# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.1.4'

# %%
Employee = pd.read_csv(r"C:\Users\sowmikanetha\Desktop\Data science\python\INX_Future_Inc_Employee_Performance_CDS_Project_Data.csv")

# %%
Employee
#Employee.head()
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %% [markdown]
# **1.INX Future Inc_Data Understandning**

# %%
#2-Over view of Data or Checking missing functionality

#Data has 1200 rows & 28 Columns with No Null values
Employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1200 non-null   object
#  1   Age                           1200 non-null   int64
#  2   Gender                        1200 non-null   object
#  3   EducationBackground           1200 non-null   object
#  4   MaritalStatus                 1200 non-null   object
#  5   EmpDepartment                 1200 non-null   object
#  6   EmpJobRole                    1200 non-null   object
#  7   BusinessTravelFrequency       1200 non-null   object
#  8   DistanceFromHome              1200 non-null   int64
#  9   EmpEducationLevel             1200 non-null   int64
#  10  EmpEnvironmentSatisfaction    1200 non-null   int64
#  11  EmpHourlyRate                 1200 non-null   int64
# ...

# %%
#3-Description of Data

#Difference in mean & 50% indicates Skewness of distribution
Employee.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %% [markdown]
# **4.Analysing the Data**

# %% [markdown]
# **5.Uni-Variate Analysis**

# %%
#6-Age

#Majority of the Employee's Age is b/w 30-43 without outliers
sns.boxplot(Employee['Age'])
Employee['Age'].describe()
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# count    1200.000000
# mean       36.918333
# std         9.087289
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
fig, axes = plt.subplots()
fig.set_size_inches(10,8,22)
sns.histplot(Employee['Age'], ax=axes)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
#7-Gender

#Majority of the employee's are Male
fig, axes = plt.subplots()
fig.set_size_inches(12,6,25)
sns.histplot(Employee['Gender'], ax=axes)
Employee['Gender'].value_counts()
# Out:
# Male      725
# Female    475
# Name: Gender, dtype: int64

# %%
#8-Marital status

#Majority of the employees are Married
fig, axes = plt.subplots()
fig.set_size_inches(12,6,25)
sns.histplot(Employee['MaritalStatus'], ax=axes)
Employee['MaritalStatus'].value_counts()
# Out:
# Married     548
# Single      384
# Divorced    268
# Name: MaritalStatus, dtype: int64

# %%
#9-EducationBackground

#Majority of EducationBackground is Life Sciences and least is Human Resources
fig, axes = plt.subplots()
fig.set_size_inches(12,6,25)
sns.histplot(Employee['EducationBackground'], ax=axes)
Employee['EducationBackground'].describe()
# Out:
# count              1200
# unique                6
# top       Life Sciences
# freq                492
# Name: EducationBackground, dtype: object

# %%
#10-EmpDepartment

#Majority of the EmpDepertment is Sales and least is Data Science
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.histplot(Employee['EmpDepartment'], ax=axes)
Employee['EmpDepartment'].describe()
# Out:
# count      1200
# unique        6
# top       Sales
# freq        373
# Name: EmpDepartment, dtype: object

# %%
#11-EmpJobRole

#Majority of the EmpJobRole is Sales Executive and least is Technical Architect
fig, axes = plt.subplots()
fig.set_size_inches(45,10,45)
sns.histplot(Employee['EmpJobRole'], ax=axes)
Employee['EmpJobRole'].describe()
# Out:
# count                1200
# unique                 19
# top       Sales Executive
# freq                  270
# Name: EmpJobRole, dtype: object

# %%
#12-BusinessTravelFrequency

#Majority of the BusinessTravelFequency is Travel_Rarely
fig, axes = plt.subplots()
fig.set_size_inches(10,5,28)
sns.histplot(Employee['BusinessTravelFrequency'], ax=axes)
Employee['BusinessTravelFrequency'].describe()
# Out:
# count              1200
# unique                3
# top       Travel_Rarely
# freq                846
# Name: BusinessTravelFrequency, dtype: object

# %%
#13-DistanceFromHome

#Majority of the DistanceFromHome range is b/w 2-7 and has no Outliers
sns.boxplot(Employee['DistanceFromHome'])
Employee['DistanceFromHome'].describe()
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# count    1200.000000
# mean        9.165833
# std         8.176636
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
#14-EmpEducationLevel

#Most of emp. education level is 2 with no Outliers
sns.boxplot(Employee['EmpEducationLevel'])
Employee['EmpEducationLevel'].describe()
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# count    1200.00000
# mean        2.89250
# std         1.04412
# min         1.00000
# 25%         2.00000
# 50%         3.00000
# 75%         4.00000
# max         5.00000
# Name: EmpEducationLevel, dtype: float64

# %%
#15-EmpEnvironmentSatisfaction

#Most of the EmpEnvironmentSatification range is low rating and has no Outliers
sns.boxplot(Employee['EmpEnvironmentSatisfaction'])
Employee['EmpEnvironmentSatisfaction'].describe()
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# count    1200.000000
# mean        2.715833
# std         1.090599
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: EmpEnvironmentSatisfaction, dtype: float64

# %%
fig, axes = plt.subplots()
fig.set_size_inches(12,8)
sns.histplot(Employee['EmpEnvironmentSatisfaction'], ax=axes)
# Out:
# <AxesSubplot:xlabel='EmpEnvironmentSatisfaction', ylabel='Count'>

# %%
#16-EmpHourlyRate    

#Majority of the EmpHourlyRate range is b/w 48-83 with no Outliers
fig, axes = plt.subplots()
fig.set_size_inches(12,5,15)
sns.histplot(Employee['EmpHourlyRate'], ax=axes)
Employee['EmpHourlyRate'].describe()
# Out:
# count    1200.000000
# mean       65.981667
# std        20.211302
# min        30.000000
# 25%        48.000000
# 50%        66.000000
# 75%        83.000000
# max       100.000000
# Name: EmpHourlyRate, dtype: float64

# %%
sns.boxplot(Employee['EmpHourlyRate'])
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EmpHourlyRate'>

# %%
#17-EmpJobInvolvement  

#Majority of the EmpJobInvolvement range has high rating
fig, axes = plt.subplots()
fig.set_size_inches(15,10)
sns.histplot(Employee['EmpJobInvolvement'], ax=axes)
Employee['EmpJobInvolvement'].value_counts()
# Out:
# 3    724
# 2    294
# 4    112
# 1     70
# Name: EmpJobInvolvement, dtype: int64

# %%
#18-EmpJobLevel  

#Majority of the EmpJobLevel has low range
fig, axes = plt.subplots()
fig.set_size_inches(30,10)
sns.histplot(Employee['EmpJobLevel'], ax=axes)
Employee['EmpJobLevel'].describe()
# Out:
# count    1200.000000
# mean        2.067500
# std         1.107836
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         5.000000
# Name: EmpJobLevel, dtype: float64

# %%
#19-EmpEnvironmentSatisfaction  

#Majority of the EmpEnvironmentSatisfaction range has low rating with no Outliers
sns.boxplot(Employee['EmpEnvironmentSatisfaction'])
Employee['EmpEnvironmentSatisfaction'].describe()
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# count    1200.000000
# mean        2.715833
# std         1.090599
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: EmpEnvironmentSatisfaction, dtype: float64

# %%
fig, axes = plt.subplots()
fig.set_size_inches(15,10)
sns.histplot(Employee['EmpEnvironmentSatisfaction'], ax=axes)
# Out:
# <AxesSubplot:xlabel='EmpEnvironmentSatisfaction', ylabel='Count'>

# %%
#20-NumCompaniesWorked 

#Majority of the employee's have worked atleast 1 company.It has 1 Outliers
sns.boxplot(Employee['NumCompaniesWorked'])
Employee['NumCompaniesWorked'].describe()
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# count    1200.000000
# mean        2.665000
# std         2.469384
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max         9.000000
# Name: NumCompaniesWorked, dtype: float64

# %%
fig, axes = plt.subplots()
fig.set_size_inches(30,10)
sns.histplot(Employee['NumCompaniesWorked'], ax=axes)
#Employee['NumCompaniesWorked'].value_counts()
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='Count'>

# %%
#21-OverTime                 

#Majority of the employee has worked in Over time
fig, axes = plt.subplots()
fig.set_size_inches(30,10)
sns.histplot(Employee['OverTime'], ax=axes)
Employee['OverTime'].value_counts()
# Out:
# No     847
# Yes    353
# Name: OverTime, dtype: int64

# %%
#22-EmpLastSalaryHikePercent      

#Majority of the EmpLastSalaryHikePercent range is b/w 12-15 with no Outlier
fig, axes = plt.subplots()
fig.set_size_inches(30,10)
sns.histplot(Employee['EmpLastSalaryHikePercent'], ax=axes)
Employee['EmpLastSalaryHikePercent'].describe()
# Out:
# count    1200.000000
# mean       15.222500
# std         3.625918
# min        11.000000
# 25%        12.000000
# 50%        14.000000
# 75%        18.000000
# max        25.000000
# Name: EmpLastSalaryHikePercent, dtype: float64

# %%
sns.boxplot(Employee['EmpLastSalaryHikePercent'])
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EmpLastSalaryHikePercent'>

# %%
#23-EmpRelationshipSatisfaction   

#Majority of the EmpRelationshipSatisfaction has low satisfaction rating
sns.boxplot(Employee['EmpRelationshipSatisfaction'])
#Employee['EmpRelationshipSatisfaction'].value_counts()
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EmpRelationshipSatisfaction'>

# %%
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.histplot(Employee['EmpRelationshipSatisfaction'], ax=axes)
Employee['EmpRelationshipSatisfaction'].describe()
# Out:
# count    1200.000000
# mean        2.725000
# std         1.075642
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: EmpRelationshipSatisfaction, dtype: float64

# %%
#24-TotalWorkExperienceInYears       

#Majority of the Emp. WorkExperienceInYear range is b/w 6-15 with Outlier
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.histplot(Employee['TotalWorkExperienceInYears'], ax=axes)
Employee['TotalWorkExperienceInYears'].describe()
# Out:
# count    1200.000000
# mean       11.330000
# std         7.797228
# min         0.000000
# 25%         6.000000
# 50%        10.000000
# 75%        15.000000
# max        40.000000
# Name: TotalWorkExperienceInYears, dtype: float64

# %%
sns.boxplot(Employee['TotalWorkExperienceInYears'])
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotalWorkExperienceInYears'>

# %%
#25-TrainingTimesLastYear         

#Majority of the Employees have attend atleast twice in TrainingTimesLastYear with Outlier
sns.boxplot(Employee['TrainingTimesLastYear'])
Employee['TrainingTimesLastYear'].value_counts()
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 2    445
# 3    413
# 5     98
# 4     98
# 1     56
# 6     46
# 0     44
# Name: TrainingTimesLastYear, dtype: int64

# %%
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.histplot(Employee['TrainingTimesLastYear'], ax=axes)
Employee['TrainingTimesLastYear'].describe()
# Out:
# count    1200.000000
# mean        2.785833
# std         1.263446
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         6.000000
# Name: TrainingTimesLastYear, dtype: float64

# %%
#26-EmpWorkLifeBalance            

#Majority of the employee has low rating in EmpWorkLifeBalance with no Outlier
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.histplot(Employee['EmpWorkLifeBalance'], ax=axes)
Employee['EmpWorkLifeBalance'].describe()
# Out:
# count    1200.000000
# mean        2.744167
# std         0.699374
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: EmpWorkLifeBalance, dtype: float64

# %%
sns.boxplot(Employee['EmpWorkLifeBalance'])
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='EmpWorkLifeBalance'>

# %%
#27-ExperienceYearsAtThisCompany

#Majority of the employee's range is b/w 3-10 in ExperienceYearsAtThisCompany with Outliers
sns.boxplot(Employee['ExperienceYearsAtThisCompany'])
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsAtThisCompany'>

# %%
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.histplot(Employee['ExperienceYearsAtThisCompany'], ax=axes)
Employee['ExperienceYearsAtThisCompany'].describe()
# Out:
# count    1200.000000
# mean        7.077500
# std         6.236899
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%        10.000000
# max        40.000000
# Name: ExperienceYearsAtThisCompany, dtype: float64

# %%
#28-ExperienceYearsInCurrentRole  

#Majority of the employee's having range b/w 2-7 in ExperienceYearsInCurrentRole with Outliers
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.histplot(Employee['ExperienceYearsInCurrentRole'], ax=axes)
Employee['ExperienceYearsInCurrentRole'].describe()
# Out:
# count    1200.000000
# mean        4.291667
# std         3.613744
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        18.000000
# Name: ExperienceYearsInCurrentRole, dtype: float64

# %%
sns.boxplot(Employee['ExperienceYearsInCurrentRole'])
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExperienceYearsInCurrentRole'>

# %%
#29-YearsSinceLastPromotion   

#Majority of the employee has range b/w 1-3 YearsSincePastPromotion with Outliers
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.histplot(Employee['YearsSinceLastPromotion'], ax=axes)
Employee['YearsSinceLastPromotion'].describe()
# Out:
# count    1200.000000
# mean        2.194167
# std         3.221560
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max        15.000000
# Name: YearsSinceLastPromotion, dtype: float64

# %%
sns.boxplot(Employee['YearsSinceLastPromotion'])
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='YearsSinceLastPromotion'>

# %%
#30-YearsWithCurrManager         

#Majority of the employee has range b/w 2-7 YearsWithCurrManager with Outlier
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.histplot(Employee['YearsWithCurrManager'], ax=axes)
Employee['YearsWithCurrManager'].describe()
# Out:
# count    1200.000000
# mean        4.105000
# std         3.541576
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        17.000000
# Name: YearsWithCurrManager, dtype: float64

# %%
sns.boxplot(Employee['YearsWithCurrManager'])
# Out:
# c:\users\sowmikanetha\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='YearsWithCurrManager'>

# %%
#31-Attrition    

#Majority of the employee has No attrition
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.histplot(Employee['Attrition'], ax=axes)
#Employee['Attrition'].describe()
Employee['Attrition'].value_counts()
# Out:
# No     1022
# Yes     178
# Name: Attrition, dtype: int64

# %%
#32-PerformanceRating 

#Majority of the employee's has 2 rating
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.histplot(Employee['PerformanceRating'], ax=axes)
Employee['PerformanceRating'].describe()
# Out:
# count    1200.000000
# mean        2.948333
# std         0.518866
# min         2.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         4.000000
# Name: PerformanceRating, dtype: float64

# %% [markdown]
# **33-Bi-Variant Analysis**

# %%
#34-Age Vs PerformanceRating
#30-40 range age people are performing well
sns.catplot(x="PerformanceRating", y="Age",data=Employee, kind='violin')

# %%
#35-EmpDepartment Vs PerformanceRating
#Development Emp Departmnent performed well compare to others with range 3-1 rating

fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.pointplot(x='EmpDepartment', y='PerformanceRating', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='EmpDepartment', ylabel='PerformanceRating'>

# %%
#36-Marital status Vs PerformanceRating
#Single's perfomed performed well with range 2-3%

sns.pointplot(x='MaritalStatus', y='PerformanceRating', data=Employee)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='PerformanceRating'>

# %%
#37-EmpJobRole Vs PerformanceRating
#Business Analyst team performed well
fig, axes = plt.subplots()
fig.set_size_inches(10,10)
sns.pointplot(x='PerformanceRating', y='EmpJobRole', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='EmpJobRole'>

# %%
#38-OverTime Vs Performance Rating

#Majority of the percentage is b/w 2.98-3 rating and high performance for working in Over time
fig, axes = plt.subplots()
fig.set_size_inches(10,10)
sns.pointplot(x='OverTime', y='PerformanceRating', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='PerformanceRating'>

# %%
#39-EmpEducationLevel

#Level 3 performed well with range of 2.95-3.00 rating
fig, axes = plt.subplots()
fig.set_size_inches(10,10)
sns.pointplot(x='EmpEducationLevel', y='PerformanceRating', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='EmpEducationLevel', ylabel='PerformanceRating'>

# %%
#DistanceFromHome Vs PerformanceRating
#fig, axes = plt.subplots()
#fig.set_size_inches(10,10)
#sns.pointplot(x='PerformanceRating', y='DistanceFromHome', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='DistanceFromHome'>

# %%
#EmpEducationLevel
#sns.catplot(x="PerformanceRating", y="DistanceFromHome",data=Employee, kind='violin')

# %% [markdown]
# **40-Multi-Variate Analysis**

# %%
#41-PerformanceRating Vs Gender in difference with Age

#Female performance is high
sns.catplot(x="PerformanceRating", y="Age", hue="Gender", data=Employee, kind='violin')

# %%
#42-Performance Rating Vs Age  in difference with EducationBackground

#Education Background Human Resourse has high performnace rating.  
fig, axes = plt.subplots()
fig.set_size_inches(10,10)
sns.pointplot(x='PerformanceRating', y='Age',  hue='EducationBackground', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='Age'>

# %%
#43-EmpDepartment Vs PerformanceRating  in difference with MaritalStatus

#Married employees PerformanceRating was high compare to others
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.pointplot(x='EmpDepartment', y='PerformanceRating',  hue='MaritalStatus', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='EmpDepartment', ylabel='PerformanceRating'>

# %%
#44-EmpDepartment Vs PerformanceRating  in difference with Age

#Age 40,57,30,56,26 are performed well in all Department(Except Sales)
fig, axes = plt.subplots()
fig.set_size_inches(13,12,28)
sns.pointplot(x='EmpDepartment', y='PerformanceRating',  hue='Age', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='EmpDepartment', ylabel='PerformanceRating'>

# %%
#45-EmpDepartment Vs PerformanceRating  in difference with Gender
#In Development team Female has best performace rating 

fig, axes = plt.subplots()
fig.set_size_inches(13,12,28)
sns.pointplot(x='EmpDepartment', y='PerformanceRating',  hue='Gender', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='EmpDepartment', ylabel='PerformanceRating'>

# %%
#46-Marital status Vs PerformanceRating  in difference with EmpDepartment
#Data science department performed will compared to other
fig, axes = plt.subplots()
fig.set_size_inches(13,5,28)
sns.pointplot(x='MaritalStatus', y='PerformanceRating',hue='EmpDepartment', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='PerformanceRating'>

# %%
#47-EmpJobRole Vs PerformanceRating  in difference with Age
#Age 50 performed well compared to others
fig, axes = plt.subplots()
fig.set_size_inches(30,13)
sns.pointplot(x='PerformanceRating', y='EmpJobRole',hue='Age', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='EmpJobRole'>

# %%
#48-EmpJobRole Vs PerformanceRating  in difference with Gender
#Male performed well in Business Analyst
fig, axes = plt.subplots()
fig.set_size_inches(10,10)
sns.pointplot(x='PerformanceRating', y='EmpJobRole',hue='Gender', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='EmpJobRole'>

# %%
#49-OverTime Vs Performance Rating in difference with Age

#Age 59 performed well in Over Time
fig, axes = plt.subplots()
fig.set_size_inches(15,10)
sns.pointplot(x='OverTime', y='PerformanceRating', hue='Age', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='PerformanceRating'>

# %%
#50-OverTime Vs Performance Rating in difference with Gender

#Female performance has best rating with 3-3.05 range
fig, axes = plt.subplots()
fig.set_size_inches(10,15)
sns.pointplot(x='OverTime', y='PerformanceRating', hue='Gender', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='PerformanceRating'>

# %%
#51-OverTime Vs Performance Rating in difference with Gender

#Senior Manager R&D has best performance rating in Over time
fig, axes = plt.subplots()
fig.set_size_inches(10,13)
sns.pointplot(x='OverTime', y='PerformanceRating', hue='EmpJobRole', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='PerformanceRating'>

# %%
#52-OverTime Vs Performance Rating in difference with Gender

#Data Science has high performance rating over time
fig, axes = plt.subplots()
fig.set_size_inches(10,10)
sns.pointplot(x='OverTime', y='PerformanceRating', hue='EmpDepartment', data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='PerformanceRating'>

# %%
#53-EmpEducationLevel Vs Performance Rating in difference with Age

#Age 45 & 35 performed well level 1 & 5
fig, axes = plt.subplots()
fig.set_size_inches(15,10)
sns.pointplot(x='EmpEducationLevel', y='PerformanceRating', hue='Age',data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='EmpEducationLevel', ylabel='PerformanceRating'>

# %%
#54-EmpEducationLevel Vs Performance Rating in difference with Gender

#Female has best performance rating in level 3
fig, axes = plt.subplots()
fig.set_size_inches(15,10)
sns.pointplot(x='EmpEducationLevel', y='PerformanceRating', hue='Gender',data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='EmpEducationLevel', ylabel='PerformanceRating'>

# %%
#55-EmpEducationLevel Vs Performance Rating in difference with EmpJobRole

#Human Resource has best performance rating
fig, axes = plt.subplots()
fig.set_size_inches(20,17)
sns.pointplot(x='EmpEducationLevel', y='PerformanceRating', hue='EmpJobRole',data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='EmpEducationLevel', ylabel='PerformanceRating'>

# %%
#56-EmpEducationLevel Vs Performance Rating in difference with EmpDepartment

#Human Resource has best performance rating
fig, axes = plt.subplots()
fig.set_size_inches(20,17)
sns.pointplot(x='EmpEducationLevel', y='PerformanceRating', hue='EmpDepartment',data=Employee, ax=axes)
# Out:
# <AxesSubplot:xlabel='EmpEducationLevel', ylabel='PerformanceRating'>
